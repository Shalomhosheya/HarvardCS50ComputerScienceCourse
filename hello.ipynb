# %%
from cs50 import get_string # pip install cs50
answer = get_string("What is your name? ")
print(f"hello {answer}")
# Out:
# hello {answer}

# %%
for i in [0,1.2]:
  print("hello") 
  
for i in range(10):
  print("hello_10")
# Out:
# hello
# hello
# hello_10
# hello_10
# hello_10
# hello_10
# hello_10
# hello_10
# hello_10
# hello_10
# hello_10
# hello_10
