# %%
from cs50 import get_string # pip install cs50
answer = get_string("What is your name? ")
print(f"hello {answer}")
# Out:
# hello {answer}

# %%
for i in [0,1.2]:
  print("hello") 
  
for i in range(10):
  print("hello_10")
  
# while True:
#     print("hello_while")
# Out:
# hello
# hello
# hello_10
# hello_10
# hello_10
# hello_10
# hello_10
# hello_10
# hello_10
# hello_10
# hello_10
# hello_10
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# hello_while
# ...

# %%
x = int(input("enter num : "))
y = int(input("enter 2nd num: "))

print(x-y)
print(x+y)
print(x/y)
print(x*y)
# Out:
# 8
# 12
# 5.0
# 20

# %%
x = input("enter num : ")

if x.lower() in["Y","y"]:
    print("agreed")
elif x.lower() in["N","n"]:
    print("disagreed")
else:
    print("invalid")
# Out:
# agreed

# %%
def main():
    for i in range(3):
        meow()  
def meow():
    print("meow")

main()
# Out:
# meow
# meow
# meow
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from cs50 import get_int # pip install cs50

def height():
    while True:
     try:
        n =  int(input("Enter num: "))
        if  n  > 0:
            return n
     except ValueError:
         print("invalid character entered")
        
def main():
    n = height()
    for i in range(n):
        print("#")    
    
main()
# Out:
# invalid
# #
# #

# %%
for i in range(10):
    print("?",end="!")
    
print()
print("?"*4)
# Out:
# ?!?!?!?!?!?!?!?!?!?!
# ????

# %%
scores = []

for i in range(3):
    score = int(input("Enter score: "))
    scores.append(score)
avearage = sum(scores)/len(scores)
print(avearage)
# Out:
# 3.0

# %%
from sys import argv
for arg in argv:
    print(arg)
# Out:
# C:\Users\shalom hosheya\AppData\Roaming\Python\Python313\site-packages\ipykernel_launcher.py
# --f="c:\Users\shalom hosheya\AppData\Roaming\jupyter\runtime\kernel-v31dced6d8ade5180b55455d5fcc607cec32a60e6a.json"

# %%
import sys

n = ["shalom","ron","jeff","jimmy"]
en = input("enter name: ")
 
for i in n:
     if en == n:
         print("found")
         sys.exit(0)
         
print("not found")
sys.exit(0)
# Out:
# not found
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\shalom hosheya\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
s = input("name: ")
d = input("2nd name: ")

if s== d:
    print("same")
else:
    print("not same")
# Out:
# same

# %%
x = 2
y = 1

x,y = y,x
print(x,y)
# Out:
# 1 2

# %%
import csv

with open("phonebook.csv","a") as file:

    name = input("name: ")
    number = input("number: ")

    writer = csv.DictWriter(file,fieldnames=["name","number"])
    writer.writerow({"name": name,"number": number})

# %%
import pyttsx3
engine = pyttsx3.init()
engine.say("hello")
engine.runAndWait()
# Out:
# DEBUG: <comtypes.client._events.CreateEventReceiver.<locals>.Sink object at 0x0000025154A5E660>.AddRef() -> 2
# DEBUG: <comtypes.client._events.CreateEventReceiver.<locals>.Sink object at 0x0000025154A5E660>.Release() -> 1
# DEBUG: <comtypes.client._events.CreateEventReceiver.<locals>.Sink object at 0x0000025154A5E660>.AddRef() -> 2
# DEBUG: wrap_outparam(<POINTER(IDispatch) ptr=0x25156cc2a90 at 2515681cbd0>)
# DEBUG: GetBestInterface(<POINTER(IDispatch) ptr=0x25156cc2a90 at 2515681cbd0>)
# DEBUG: Does NOT implement IProvideClassInfo, trying IProvideClassInfo2
# DEBUG: Does NOT implement IProvideClassInfo/IProvideClassInfo2
# DEBUG: Release <POINTER(IUnknown) ptr=0x25153bb88e0 at 2515681d0d0>
# DEBUG: Default interface is {C74A3ADC-B727-4500-A84A-B526721C8B8C}
# DEBUG: Release <POINTER(IUnknown) ptr=0x25156cc2a90 at 2515681c7d0>
# DEBUG: GetModule(TLIBATTR(GUID={C866CA3A-32F7-11D2-9602-00C04F8EE628}, Version=5.4, LCID=0, FLags=0x8))
# ...

# %%
import pyttsx3 #pip install pyttsx3

# Initialize the TTS engine
engine = pyttsx3.init()

# Text to speak
text = "Hello, world! This is an offline text to speech example using pyttsx3."

# Enqueue the text to be spoken
engine.say(text)

# Block while processing all the currently queued commands
engine.runAndWait()
# Out:
# DEBUG: <comtypes.client._events.CreateEventReceiver.<locals>.Sink object at 0x0000025154A5E660>.AddRef() -> 2
# DEBUG: <comtypes.client._events.CreateEventReceiver.<locals>.Sink object at 0x0000025154A5E660>.Release() -> 1
# DEBUG: <comtypes.client._events.CreateEventReceiver.<locals>.Sink object at 0x0000025154A5E660>.AddRef() -> 2
# DEBUG: wrap_outparam(<POINTER(IDispatch) ptr=0x25156cc2a90 at 2515681cd50>)
# DEBUG: GetBestInterface(<POINTER(IDispatch) ptr=0x25156cc2a90 at 2515681cd50>)
# DEBUG: Does NOT implement IProvideClassInfo, trying IProvideClassInfo2
# DEBUG: Does NOT implement IProvideClassInfo/IProvideClassInfo2
# DEBUG: Release <POINTER(IUnknown) ptr=0x25153bb88e0 at 2515681dad0>
# DEBUG: Default interface is {C74A3ADC-B727-4500-A84A-B526721C8B8C}
# DEBUG: Release <POINTER(IUnknown) ptr=0x25156cc2a90 at 2515681d750>
# DEBUG: GetModule(TLIBATTR(GUID={C866CA3A-32F7-11D2-9602-00C04F8EE628}, Version=5.4, LCID=0, FLags=0x8))
# ...
